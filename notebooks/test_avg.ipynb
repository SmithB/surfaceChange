# %%
import pointCollection as pc
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
import re
import glob
import h5py
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
! ls /Volumes/ice2/ben/ATL14_test/IS2/U07/*/*.h5
# Out:
# /Volumes/ice2/ben/ATL14_test/IS2/U07/z03xlooser_dt10xlooser_40km/dz_mosaic.h5
# /Volumes/ice2/ben/ATL14_test/IS2/U07/z03xlooser_dt10xlooser_40km/z0_mosaic.h5
# /Volumes/ice2/ben/ATL14_test/IS2/U07/z03xlooser_dt10xlooser_80km_backup/dz_mosaic.h5
# /Volumes/ice2/ben/ATL14_test/IS2/U07/z03xlooser_dt10xlooser_80km_backup/z0_mosaic.h5
# /Volumes/ice2/ben/ATL14_test/IS2/U07/z03xlooser_dt10xlooser_80km/dz_mosaic.h5
# /Volumes/ice2/ben/ATL14_test/IS2/U07/z03xlooser_dt10xlooser_80km/z0_mosaic.h5

# %%
maps={}
run_dir='/Volumes/ice2/ben/ATL14_test/IS2/U07/z03xlooser_dt10xlooser_80km/'

maps['z0']=pc.grid.data().from_h5(run_dir+'/z0_mosaic.h5', group='z0', field_mapping={'z':'z0'})
maps['dz']=pc.grid.data().from_h5(run_dir+'/dz_mosaic.h5', group='dz', field_mapping={'z':'dz'})

# %%
plt.figure(1, figsize=[8, 4]); 
plt.subplot(1,2,1)
plt.imshow(np.gradient(maps['z0'].z[:,:,0])[0], extent=maps['z0'].extent, vmin=-3, vmax=3,  origin='lower',cmap='gray')
plt.subplot(1,2,2)
plt.imshow(maps['dz'].z[:,:,4]- maps['dz'].z[:,:,0], extent=maps['dz'].extent, vmin=-3, vmax=3,  origin='lower',cmap='Spectral')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
x0=-328000
y0=-1.7e6
plt.plot(x0, y0, 'm*')

[x0,y0]
# Out:
# [-328000, -1700000.0]
